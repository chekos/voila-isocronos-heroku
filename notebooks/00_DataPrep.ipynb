# %% [markdown]
# # isocronos desde las universidades de california
# #### Una app de voila para visualizar isocronos de las universidades publicas de california.
#
# <details>
#     <summary><strong>Meta</strong></summary>
#     La meta de este notebook es abrir el archivo zip y preparar los datos para la aplicación.
#     <ul>
#         <li> Metas mensurables </li>
#         <li> Limpiar datos y valores desde el archivo zip y crear un archivo csv listo para usar</li>
#     </ul>
# </details>
#
# <details>
#     <summary><strong>Contexto</strong></summary>
#     Descargamos los datos desde IPEDS con la información de las universidades y colegios públicas de 2 o 4 años de California.
# </details>

# %%
import pandas as pd
from zipfile import ZipFile
from pathlib import Path
from herramientas import arbol
import arrow
hoy = arrow.now().format("DD-MMM-YY", locale = 'es')

hoy
# Out:
# '05-jul-19'

# %%
DATOS_BRUTOS = Path("../datos/brutos/")
DATOS_INTERINOS = Path("../datos/interinos/")
DATOS_PROCESADOS = Path("../datos/procesados/")
DATOS_EXTERNOS = Path("../datos/externos/")

# %%
arbol(DATOS_BRUTOS)
# Out:
# + ..\datos\brutos
#     + ipeds-julio-5.zip

# %%
ZipFile(DATOS_BRUTOS / 'ipeds-julio-5.zip').extractall(DATOS_BRUTOS / 'datos_ipeds/')

# %%
arbol(DATOS_BRUTOS)
# Out:
# + ..\datos\brutos
#     + datos_ipeds
#         + Data_7-5-2019---729.csv
#         + ValueLabels_7-5-2019---729.csv
#     + ipeds-julio-5.zip

# %%
datos = pd.read_csv(DATOS_BRUTOS / 'datos_ipeds' / 'Data_7-5-2019---729.csv')
valores = pd.read_csv(DATOS_BRUTOS / 'datos_ipeds' / 'ValueLabels_7-5-2019---729.csv')

# %%
datos.head()
# Out:
#    UnitID           Institution Name  Sector of institution (HD2017)  \
# 0  108807      Allan Hancock College                               4
# 1  109208     American River College                               4
# 2  109350    Antelope Valley College                               1
# 3  109819        Bakersfield College                               1
# 4  109907  Barstow Community College                               4
#
#   Institution name alias (HD2017) Institution (entity) name (HD2017)  \
# 0                             NaN              Allan Hancock College
# 1            American River | ARC             American River College
# 2                             NaN            Antelope Valley College
# 3                             NaN                Bakersfield College
# 4                             NaN          Barstow Community College
#
#   Street address or post office box (HD2017)  \
# 0                    800 South College Drive
# 1                        4700 College Oak Dr
# 2                           3041 West  Ave K
# 3                           1801 Panorama Dr
# 4                          2700 Barstow Road
#
#   City location of institution (HD2017) ZIP code (HD2017)  \
# 0                           Santa Maria        93454-6399
# 1                            Sacramento        95841-4286
# 2                             Lancaster        93536-5426
# 3                           Bakersfield        93305-1299
# 4                               Barstow             92311
#
#   Institution's internet website address (HD2017)  \
# 0                         www.hancockcollege.edu/
# 1                            www.arc.losrios.edu/
# 2                                     www.avc.edu
# 3                     www.bakersfieldcollege.edu/
# 4                                 www.barstow.edu
#
#            Financial aid office web address (HD2017)  \
# 0     www.hancockcollege.edu/financial_aid/index.php
# 1  www.arc.losrios.edu/Support_Services/Financial...
# 2                www.avc.edu/studentservices/finaid/
# 3                 www.bakersfieldcollege.edu/finaid/
# 4                 www.barstow.edu/Financial-Aid.html
#
#          Admissions office web address (HD2017)  \
# 0    www.hancockcollege.edu/admissions_records/
# 1  www.arc.losrios.edu/prospective_students.htm
# 2         www.avc.edu/studentservices/adminrec/
# 3        www.bakersfieldcollege.edu/admissions/
# 4    www.barstow.edu/Admission-and-Records.html
#
#              Online application web address (HD2017)  Unnamed: 12
# 0            www.hancockcollege.edu/future_students/          NaN
# 1                    www.losrios.edu/lrc/lrc_app.php          NaN
# 2   www.avc.edu/studentservices/adminrec/applyonline          NaN
# 3           https://www.bakersfieldcollege.edu/apply          NaN
# 4  https://www.opencccapply.net/uPortal/render.us...          NaN

# %%
valores.head()
# Out:
#                      VariableName  Value               ValueLabel
# 0  Sector of institution (HD2017)      1  Public, 4-year or above
# 1  Sector of institution (HD2017)      4           Public, 2-year

# %% [markdown]
# # Sistemas educativos
# En California existen 3 sistemas universitarios: _California State University_ (CSU), _University of California_ (UC) y _California Community Colleges_ (CCC).
# CCC son colegios comunitarios que normalmente solo otorgan títulos _Associate's_ (de 2 años). Desde hace unos años atrás, los CCCs pueden otorgar licenciaturas también (_Bachelor's_) lo cual significa que algunos de estos CCCs estan clasificados como _Public, 4-year or above_.
#
# Crearemos nuestras etiquetas primero para CSU (23 universidades), luego UC (11 universidades) y el resto serán los CCCs.

# %%
valores_sector = {}

for indice, valor in valores[['Value', 'ValueLabel']].iterrows():
    valores_sector[valor[0]] = valor[1]
    
valores_sector
# Out:
# {1: 'Public, 4-year or above', 4: 'Public, 2-year'}

# %%
datos['Sector of institution (HD2017)'] = datos['Sector of institution (HD2017)'].map(valores_sector)

datos.head()
# Out:
#    UnitID           Institution Name Sector of institution (HD2017)  \
# 0  108807      Allan Hancock College                 Public, 2-year
# 1  109208     American River College                 Public, 2-year
# 2  109350    Antelope Valley College        Public, 4-year or above
# 3  109819        Bakersfield College        Public, 4-year or above
# 4  109907  Barstow Community College                 Public, 2-year
#
#   Institution name alias (HD2017) Institution (entity) name (HD2017)  \
# 0                             NaN              Allan Hancock College
# 1            American River | ARC             American River College
# 2                             NaN            Antelope Valley College
# 3                             NaN                Bakersfield College
# 4                             NaN          Barstow Community College
#
#   Street address or post office box (HD2017)  \
# 0                    800 South College Drive
# 1                        4700 College Oak Dr
# 2                           3041 West  Ave K
# 3                           1801 Panorama Dr
# 4                          2700 Barstow Road
#
#   City location of institution (HD2017) ZIP code (HD2017)  \
# 0                           Santa Maria        93454-6399
# 1                            Sacramento        95841-4286
# 2                             Lancaster        93536-5426
# 3                           Bakersfield        93305-1299
# 4                               Barstow             92311
#
#   Institution's internet website address (HD2017)  \
# 0                         www.hancockcollege.edu/
# 1                            www.arc.losrios.edu/
# 2                                     www.avc.edu
# 3                     www.bakersfieldcollege.edu/
# 4                                 www.barstow.edu
#
#            Financial aid office web address (HD2017)  \
# 0     www.hancockcollege.edu/financial_aid/index.php
# 1  www.arc.losrios.edu/Support_Services/Financial...
# 2                www.avc.edu/studentservices/finaid/
# 3                 www.bakersfieldcollege.edu/finaid/
# 4                 www.barstow.edu/Financial-Aid.html
#
#          Admissions office web address (HD2017)  \
# 0    www.hancockcollege.edu/admissions_records/
# 1  www.arc.losrios.edu/prospective_students.htm
# 2         www.avc.edu/studentservices/adminrec/
# 3        www.bakersfieldcollege.edu/admissions/
# 4    www.barstow.edu/Admission-and-Records.html
#
#              Online application web address (HD2017)  Unnamed: 12
# 0            www.hancockcollege.edu/future_students/          NaN
# 1                    www.losrios.edu/lrc/lrc_app.php          NaN
# 2   www.avc.edu/studentservices/adminrec/applyonline          NaN
# 3           https://www.bakersfieldcollege.edu/apply          NaN
# 4  https://www.opencccapply.net/uPortal/render.us...          NaN

# %%
mascara_4_años = datos['Sector of institution (HD2017)'] == "Public, 4-year or above"
mascara_2_años = datos['Sector of institution (HD2017)'] == 'Public, 2-year'

mascara_CSU = datos['Institution Name'].str.contains("State")
mascara_UC = datos['Institution Name'].str.contains("University of California")
mascara_CCC = datos['Institution Name'].str.contains("College")

# %% [markdown]
# #### Revisemos que los números cuadren

# %%
datos[mascara_4_años & mascara_CSU].shape
# Out:
# (23, 13)

# %%
datos[mascara_4_años & mascara_UC].shape
# Out:
# (11, 13)

# %%
datos[mascara_2_años & mascara_CCC].shape
# Out:
# (100, 13)

# %% [markdown]
# Los CCC deberían ser 114 pero el resto de los números cuadran. Prosigamos con los que tenemos y arreglaremos el resto más tarde.

# %%
datos.loc[mascara_4_años & mascara_CSU, 'Sistema'] = 'CSU'
datos.loc[mascara_4_años & mascara_UC, 'Sistema'] = 'UC'
datos.loc[mascara_2_años & mascara_CCC, 'Sistema'] = 'CCC'

# %% [markdown]
# Veamos el resto

# %%
datos[datos['Sistema'].isna()]
# Out:
#      UnitID                                   Institution Name  \
# 2    109350                            Antelope Valley College
# 3    109819                                Bakersfield College
# 50   113236                                    Cypress College
# 54   413802  East San Gabriel Valley Regional Occupational ...
# 58   114433           Feather River Community College District
# 60   114716                                   Foothill College
# 67   383084                 Hacienda La Puente Adult Education
# 89   118912                                  MiraCosta College
# 91   118976                             Modesto Junior College
# 107  121886                                  Rio Hondo College
# 113  122375                             San Diego Mesa College
# 120  121619                                  Santa Ana College
# 122  122977                               Santa Monica College
# 125  123299                                     Shasta College
# 127  123509                                    Skyline College
# 128  123563                           Solano Community College
# 147  125471                           West Los Angeles College
#
#     Sector of institution (HD2017)  \
# 2          Public, 4-year or above
# 3          Public, 4-year or above
# 50         Public, 4-year or above
# 54                  Public, 2-year
# 58         Public, 4-year or above
# 60         Public, 4-year or above
# 67                  Public, 2-year
# 89         Public, 4-year or above
# 91         Public, 4-year or above
# 107        Public, 4-year or above
# 113        Public, 4-year or above
# 120        Public, 4-year or above
# 122        Public, 4-year or above
# 125        Public, 4-year or above
# 127        Public, 4-year or above
# 128        Public, 4-year or above
# 147        Public, 4-year or above
#
#                        Institution name alias (HD2017)  \
# 2                                                  NaN
# 3                                                  NaN
# 50                                                 NaN
# 54                                                 NaN
# 58                               Feather River College
# 60                                                 NaN
# 67                                                 NaN
# 89                                                 NaN
# 91                                                 MJC
# 107                                          RHCCD|RHC
# 113                                                NaN
# 120                                                SAC
# 122                                                SMC
# 125                                                NaN
# 127                                                NaN
# 128                                     Solano College
# 147  West LA College |West L.A. College |West LA |W...
#
#                     Institution (entity) name (HD2017)  \
# 2                              Antelope Valley College
# 3                                  Bakersfield College
# 50                                     Cypress College
# 54   East San Gabriel Valley Regional Occupational ...
# 58            Feather River Community College District
# 60                                    Foothill College
# 67                  Hacienda La Puente Adult Education
# 89                                   MiraCosta College
# 91                              Modesto Junior College
# 107                                  Rio Hondo College
# 113                             San Diego Mesa College
# 120                                  Santa Ana College
# 122                               Santa Monica College
# 125                                     Shasta College
# 127                                    Skyline College
# 128                           Solano Community College
# 147                           West Los Angeles College
#
#     Street address or post office box (HD2017)  \
# 2                             3041 West  Ave K
# 3                             1801 Panorama Dr
# 50                            9200 Valley View
# 54                        1501 W Del Norte St.
# 58                        570 Golden Eagle Ave
# 60                           12345 El Monte Rd
# 67                         14101 E. Nelson Ave
# 89                           One Barnard Drive
# 91                             435 College Ave
# 107                       3600 Workman Mill Rd
# 113                       7250 Mesa College Dr
# 120                        1530 W. 17th Street
# 122                             1900 Pico Blvd
# 125                     11555 Old Oregon Trail
# 127                            3300 College Dr
# 128                      4000 Suisun Valley Rd
# 147                       9000 Overland Avenue
#
#     City location of institution (HD2017) ZIP code (HD2017)  \
# 2                               Lancaster        93536-5426
# 3                             Bakersfield        93305-1299
# 50                                Cypress        90630-5897
# 54                            West Covina             91790
# 58                                 Quincy        95971-9124
# 60                        Los Altos Hills             94022
# 67                              La Puente        91746-0002
# 89                              Oceanside        92056-3899
# 91                                Modesto        95350-5800
# 107                              Whittier        90601-1616
# 113                             San Diego        92111-4998
# 120                             Santa Ana        92706-3398
# 122                          Santa Monica        90405-1628
# 125                               Redding             96003
# 127                             San Bruno        94066-1698
# 128                             Fairfield        94534-3197
# 147                           Culver City        90230-3519
#
#     Institution's internet website address (HD2017)  \
# 2                                       www.avc.edu
# 3                       www.bakersfieldcollege.edu/
# 50                           www.cypresscollege.edu
# 54                                  www.esgvrop.org
# 58                                      www.frc.edu
# 60                                 www.foothill.edu
# 67                                    www.hlpae.com
# 89                                www.miracosta.edu
# 91                                      www.mjc.edu
# 107                                www.riohondo.edu
# 113                                 www.sdmesa.edu/
# 120                                     www.sac.edu
# 122                                     www.smc.edu
# 125                           www.shastacollege.edu
# 127                              skylinecollege.edu
# 128                                  www.solano.edu
# 147                                    www.wlac.edu
#
#              Financial aid office web address (HD2017)  \
# 2                  www.avc.edu/studentservices/finaid/
# 3                   www.bakersfieldcollege.edu/finaid/
# 50      www.cypresscollege.edu/admissions/financialAid
# 54                                     www.esgvrop.org
# 58                           www.frc.edu/financialaid/
# 60                  https://foothill.edu/financialaid/
# 67                                                 NaN
# 89   www.miracosta.edu/studentservices/financialaid...
# 91                 www.mjc.edu/studentservices/finaid/
# 107                    www.riohondo.edu/financial-aid/
# 113           www.sdmesa.edu/financial-aid/index.shtml
# 120  www.sac.edu/StudentServices/FinancialAid/Pages...
# 122  www.smc.edu/EnrollmentDevelopment/FinAid/Pages...
# 125  www.shastacollege.edu/Student%20Services/Finan...
# 127      www.skylinecollege.edu/financialaid/index.php
# 128                      www.solano.edu/financial_aid/
# 147              www.wlac.edu/Financial-Aid/index.aspx
#
#                 Admissions office web address (HD2017)  \
# 2                www.avc.edu/studentservices/adminrec/
# 3               www.bakersfieldcollege.edu/admissions/
# 50                   www.cypresscollege.edu/admissions
# 54                                     www.esgvrop.org
# 58                    www.frc.edu/admissions/index.cfm
# 60                     www.foothill.edu/admissions.php
# 67                                                 NaN
# 89   www.miracosta.edu/studentservices/admissions/i...
# 91             www.mjc.edu/studentservices/enrollment/
# 107                       www.riohondo.edu/admissions/
# 113  www.sdmesa.edu/admissions/index.shtml?utm_sour...
# 120  www.sac.edu/StudentServices/AdmissionsRecords/...
# 122  www.smc.edu/EnrollmentDevelopment/Admissions/P...
# 125  www.shastacollege.edu/Student%20Services/Enrol...
# 127        www.skylinecollege.edu/admissions/apply.php
# 128                                 www.solano.edu/ar/
# 147                 www.wlac.edu/Admissions/index.aspx
#
#                Online application web address (HD2017)  Unnamed: 12 Sistema
# 2     www.avc.edu/studentservices/adminrec/applyonline          NaN     NaN
# 3             https://www.bakersfieldcollege.edu/apply          NaN     NaN
# 50    www.cypresscollege.edu/admissions/gettingStarted          NaN     NaN
# 54                                     www.esgvrop.org          NaN     NaN
# 58   https://banner.frc.edu/pls/PROD/bwskalog.P_Dis...          NaN     NaN
# 60                             www.foothill.edu/apply/          NaN     NaN
# 67                                                 NaN          NaN     NaN
# 89   www.miracosta.edu/studentservices/applyenroll/...          NaN     NaN
# 91   www.mjc.edu/studentservices/enrollment/admissi...          NaN     NaN
# 107                      www.riohondo.edu/get-started/          NaN     NaN
# 113                               studentweb.sdccd.edu          NaN     NaN
# 120  www.opencccapply.net/uPortal/render.userLayout...          NaN     NaN
# 122  www.smc.edu/EnrollmentDevelopment/Admissions/P...          NaN     NaN
# 125  www.shastacollege.edu/Student%20Services/Enrol...          NaN     NaN
# 127        www.skylinecollege.edu/admissions/apply.php          NaN     NaN
# 128  https://www.opencccapply.net/uPortal/render.us...          NaN     NaN
# 147  www.laccd.edu/Students/opencccapply/applywlac/...          NaN     NaN

# %% [markdown]
# Parece ser que existen dos instituciones de educación para adultos y el resto de los colegios CCC estan clasificados como _Public, 4-year or above_. Así que utilicemos esa mascara y borremos las 2 instituciones que no son universidades o colegios.

# %%
datos.loc[mascara_4_años & mascara_CCC, 'Sistema'] = 'CCC'

# %%
datos = datos[~(datos['Sistema'].isna())]

# %%
datos.shape
# Out:
# (149, 14)

# %% [markdown]
# Guardemos solo nuestras columnas de interés

# %%
datos.columns
# Out:
# Index(['UnitID', 'Institution Name', 'Sector of institution (HD2017)',
#        'Institution name alias (HD2017)', 'Institution (entity) name (HD2017)',
#        'Street address or post office box (HD2017)',
#        'City location of institution (HD2017)', 'ZIP code (HD2017)',
#        'Institution's internet website address (HD2017)',
#        'Financial aid office web address (HD2017)',
#        'Admissions office web address (HD2017)',
#        'Online application web address (HD2017)', 'Unnamed: 12', 'Sistema'],
#       dtype='object')

# %%
columnas_de_interes = [
    'Sistema',
    'Institution Name', 
    'Institution name alias (HD2017)', 
    'Institution (entity) name (HD2017)',
    'Street address or post office box (HD2017)',
    'City location of institution (HD2017)',
    'ZIP code (HD2017)',
    "Institution's internet website address (HD2017)",
    'Financial aid office web address (HD2017)',
    'Admissions office web address (HD2017)',
    'Online application web address (HD2017)',
]

# %%
datos_limpios = datos[columnas_de_interes].copy()

# %%
datos_limpios.shape
# Out:
# (149, 11)

# %%
datos_limpios.head()
# Out:
#   Sistema           Institution Name Institution name alias (HD2017)  \
# 0     CCC      Allan Hancock College                             NaN
# 1     CCC     American River College            American River | ARC
# 2     CCC    Antelope Valley College                             NaN
# 3     CCC        Bakersfield College                             NaN
# 4     CCC  Barstow Community College                             NaN
#
#   Institution (entity) name (HD2017)  \
# 0              Allan Hancock College
# 1             American River College
# 2            Antelope Valley College
# 3                Bakersfield College
# 4          Barstow Community College
#
#   Street address or post office box (HD2017)  \
# 0                    800 South College Drive
# 1                        4700 College Oak Dr
# 2                           3041 West  Ave K
# 3                           1801 Panorama Dr
# 4                          2700 Barstow Road
#
#   City location of institution (HD2017) ZIP code (HD2017)  \
# 0                           Santa Maria        93454-6399
# 1                            Sacramento        95841-4286
# 2                             Lancaster        93536-5426
# 3                           Bakersfield        93305-1299
# 4                               Barstow             92311
#
#   Institution's internet website address (HD2017)  \
# 0                         www.hancockcollege.edu/
# 1                            www.arc.losrios.edu/
# 2                                     www.avc.edu
# 3                     www.bakersfieldcollege.edu/
# 4                                 www.barstow.edu
#
#            Financial aid office web address (HD2017)  \
# 0     www.hancockcollege.edu/financial_aid/index.php
# 1  www.arc.losrios.edu/Support_Services/Financial...
# 2                www.avc.edu/studentservices/finaid/
# 3                 www.bakersfieldcollege.edu/finaid/
# 4                 www.barstow.edu/Financial-Aid.html
#
#          Admissions office web address (HD2017)  \
# 0    www.hancockcollege.edu/admissions_records/
# 1  www.arc.losrios.edu/prospective_students.htm
# 2         www.avc.edu/studentservices/adminrec/
# 3        www.bakersfieldcollege.edu/admissions/
# 4    www.barstow.edu/Admission-and-Records.html
#
#              Online application web address (HD2017)
# 0            www.hancockcollege.edu/future_students/
# 1                    www.losrios.edu/lrc/lrc_app.php
# 2   www.avc.edu/studentservices/adminrec/applyonline
# 3           https://www.bakersfieldcollege.edu/apply
# 4  https://www.opencccapply.net/uPortal/render.us...

# %%
nombres_columnas_español = [
    'Sistema',
    'Nombre', 
    'Alias', 
    'Nombre (alternativo)',
    'Dirección',
    'Ciudad',
    'Código postal',
    "Sitio de internet",
    'Sitio de internet (ayuda financiera)',
    'Sitio de internet (oficina de adminsiones)',
    'Sitio de internet (aplicación en línea)',
]

# %%
datos_limpios.columns = nombres_columnas_español

# %%
# Dirección para isocronos
datos_limpios['Dirección OSMNx'] = datos_limpios['Dirección'] + ", " + datos_limpios['Ciudad'] + ", CA " + datos_limpios['Código postal']

# %%
datos_limpios.to_csv(DATOS_PROCESADOS / f'base_de_datos-{hoy}.csv', encoding = 'utf-8', index = False,)
